# %% [markdown]
# # Homework 1: Ung Vises

# %% [markdown]
# Set up the environment
#
# You need to install Python, NumPy, Pandas, Matplotlib and Seaborn.

# %% [markdown]
# ## Install the requirement libraries
# 1. Run this command:
# 2. Type: pip install numpy pandas matplotlib seaborn
# 3. Install numpy, pandas, matplotlip and Seaborn
# - pip install numpy
# - pip install pandas
# - pip install matplotlib
# - pip install seaborn

# %% [markdown]
# ## Q1. Pandas version
# What's the version of Pandas that you installed?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Seaborn:", sns.__version__)
print("Matplotlib:", plt.matplotlib.__version__)
# Out:
# Pandas: 2.2.3
# NumPy: 2.1.3
# Seaborn: 0.13.2
# Matplotlib: 3.10.0

# %% [markdown]
# Getting the data
# For this homework, we'll use the Laptops Price dataset. Download it from here.
#
# You can do it with wget:
#
# wget https://raw.githubusercontent.com/sithvothykiv/ml-laptop-dataset/refs/heads/main/laptops.csv
#
# Or just open it with your browser and click "Save as...".
#
# Now read it with Pandas.

# %%
import urllib.request
url = "https://raw.githubusercontent.com/sithvothykiv/ml-laptop-dataset/main/laptops.csv"
urllib.request.urlretrieve(url, "laptops.csv")

import pandas as pd
df = pd.read_csv("laptops.csv")
df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# ...

# %% [markdown]
# ## Q2. Records count How many records are in the dataset?

# %% [markdown]
# Q2. Records count
# How many records are in the dataset?
#
# -	12
# -	1000
# -	2160
# -	12160

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laptop        2160 non-null   object
#  1   Status        2160 non-null   object
#  2   Brand         2160 non-null   object
#  3   Model         2160 non-null   object
#  4   CPU           2160 non-null   object
#  5   RAM           2160 non-null   int64
#  6   Storage       2160 non-null   int64
#  7   Storage type  2118 non-null   object
#  8   GPU           789 non-null    object
#  9   Screen        2156 non-null   float64
#  10  Touch         2160 non-null   object
#  11  Final Price   2160 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 202.6+ KB

# %% [markdown]
# ## Q3. Laptop brands
# How many laptop brands are presented in the dataset?
# 12
# 27
# 28
# 2160

# %%
laptop_brand = df["Brand"].nunique()
laptop_brand
# Out:
# 27

# %% [markdown]
# ## Q4. Missing values
# How many columns in the dataset have missing values?
#
# -	0
# -	1
# -	2
# -	3

# %%
# Count of columns that contain at least one missing value
num_missing_cols = df.isna().any().sum()
num_missing_cols
# Out:
# np.int64(3)

# %% [markdown]
# ## Q5. Maximum final price
# What's the maximum final price of Dell notebooks in the dataset?
#
# -	869
# -	3691
# -	3849
# -	3936

# %%
# Filter Dell laptops and get the maximum final price
max_dell_price = df[df["Brand"] == "Dell"]["Final Price"].max()
max_dell_price
# Out:
# 3936.0

# %% [markdown]
# ## Q6. Median value of Screen
# 1.	Find the median value of Screen column in the dataset.
# 2.	Next, calculate the most frequent value of the same Screen column.
# 3.	Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.
# 4.	Now, calculate the median value of Screen once again.
#
# Has it changed?
#
# Hint: refer to existing mode and median functions to complete the task.
#
# -	Yes
# -	No

# %%
# 1. Find the median value of Screen column in the dataset.
median_screen = df["Screen"].median()
median_screen
# Out:
# 15.6

# %%
# 2. Next, calculate the most frequent value of the same Screen column
most_frequent_screen = df["Screen"].mode()[0]
most_frequent_screen
# Out:
# np.float64(15.6)

# %%
# 3. Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.
# Fill NaNs with the most frequent value
df["Screen1"] = df["Screen"].fillna(most_frequent_screen)

# %%
 # Fill missing with the mode

before_median = df["Screen"].median()

# Fill missing values with the mode
most_freq = df["Screen"].mode().iloc[0]
df["Screen"] = df["Screen"].fillna(most_freq)

after_median = df["Screen"].median()

before_median, after_median
# Out:
# (15.6, 15.6)
