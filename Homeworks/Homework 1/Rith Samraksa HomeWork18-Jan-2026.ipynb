# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/sithvothykiv/ml-laptop-dataset/refs/heads/main/laptops.csv")

# %%
#Q1. Pandas version (2.2.3)
pd.__version__
# Out:
# '2.2.3'

# %%
#Q2. Records count (2160)
df.shape
# Out:
# (2160, 12)

# %%
#Q3. Laptop brands (27)

# %%
df["Brand"].nunique()
# Out:
# 27

# %%
#Q4. Missing values (0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laptop        2160 non-null   object
#  1   Status        2160 non-null   object
#  2   Brand         2160 non-null   object
#  3   Model         2160 non-null   object
#  4   CPU           2160 non-null   object
#  5   RAM           2160 non-null   int64
#  6   Storage       2160 non-null   int64
#  7   Storage type  2118 non-null   object
#  8   GPU           789 non-null    object
#  9   Screen        2156 non-null   float64
#  10  Touch         2160 non-null   object
#  11  Final Price   2160 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 202.6+ KB

# %%
#Q5. Maximum final price (3936)
Dell_notebooks=df[df['Brand']=='Dell']

# %%
Dell_notebooks['Final Price'].max()
# Out:
# 3936.0

# %%
#Q6. Median value of Screen
#1.Find the median value of Screen column in the dataset. (15.6)
df['Screen'].median()
# Out:
# 15.6

# %%
#2.Next, calculate the most frequent value of the same Screen column.
most_frequent=df['Screen'].mode()[0]
most_frequent
# Out:
# np.float64(15.6)

# %%
#3.3.Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.
df['Screen'].fillna(most_frequent)
# Out:
# 0       15.6
# 1       15.6
# 2       15.6
# 3       15.6
# 4       15.6
#         ...
# 2155    17.3
# 2156    17.3
# 2157    17.3
# 2158    13.4
# 2159    13.4
# Name: Screen, Length: 2160, dtype: float64

# %%
df['Screen'].median()
# Out:
# 15.6

# %%
#Has it changed? (No)
