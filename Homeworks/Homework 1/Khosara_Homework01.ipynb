# %% [markdown]
# # Homework 01

# %% [markdown]
# Q1. Pandas version
#
# What's the version of Pandas that you installed?

# %%
pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# Getting the data
# For this homework, we'll use the Laptops Price dataset.

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ML Course/HW 01/Laptops Price dataset.csv")

# %% [markdown]
# Q2. Records count
#
# How many records are in the dataset?

# %%
df.shape
# Out:
# (2160, 12)

# %% [markdown]
# Q3. Laptop brands
#
# How many laptop brands are presented in the dataset?

# %%
df['Brand'].nunique()
#df['Brand'].unique().tolist()
# Out:
# 27

# %% [markdown]
# Q4. Missing values
#
# How many columns in the dataset have missing values?

# %%
df.isnull().any().sum()
# Out:
# np.int64(3)

# %% [markdown]
# Q5. Maximum final price
#
# What's the maximum final price of Dell notebooks in the dataset?

# %%
df.loc[df['Brand']=='Dell','Final Price'].max()
# Out:
# 3936.0

# %% [markdown]
# Q6. Median value of Screen
#
# 1.	Find the median value of Screen column in the dataset.
#
# 2.	Next, calculate the most frequent value of the same Screen column.
#
# 3.	Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.
#
# 4.	Now, calculate the median value of Screen once again.

# %%
#1. Find the median value of Screen column in the dataset.
df['Screen'].median()
# Out:
# 15.6

# %%
#2.	Next, calculate the most frequent value of the same Screen column.
df['Screen'].mode()
# Out:
# 0    15.6
# Name: Screen, dtype: float64

# %%
#3.	Use fillna method to fill the missing values in Screen column with the most frequent value from the previous step.
print('Before fillna:', df['Screen'].isna().sum())
df['Screen'] = df['Screen'].fillna(df['Screen'].mode()[0])
print('After fillna:', df['Screen'].isna().sum())
# Out:
# Before fillna: 4
# After fillna: 0

# %%
#4.	Now, calculate the median value of Screen once again.
df['Screen'].median()
# Out:
# 15.6
